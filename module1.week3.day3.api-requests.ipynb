# %%
import requests

# %%
response = requests.get("http://api.open-notify.org/astros.json")
print('reponse code ', response)
# Out:
# reponse code  <Response [200]>

# %%
result = response.json()
result
# Out:
# {'people': [{'name': 'Christina Koch', 'craft': 'ISS'},
#   {'name': 'Alexander Skvortsov', 'craft': 'ISS'},
#   {'name': 'Luca Parmitano', 'craft': 'ISS'},
#   {'name': 'Andrew Morgan', 'craft': 'ISS'},
#   {'name': 'Oleg Skripochka', 'craft': 'ISS'},
#   {'name': 'Jessica Meir', 'craft': 'ISS'}],
#  'number': 6,
#  'message': 'success'}

# %%
type(result)
# Out:
# dict

# %%
print('Currently there are ', result['number'], ' people in space')
# Out:
# Currently there are  6  people in space

# %%
result['people']
# Out:
# [{'name': 'Christina Koch', 'craft': 'ISS'},
#  {'name': 'Alexander Skvortsov', 'craft': 'ISS'},
#  {'name': 'Luca Parmitano', 'craft': 'ISS'},
#  {'name': 'Andrew Morgan', 'craft': 'ISS'},
#  {'name': 'Oleg Skripochka', 'craft': 'ISS'},
#  {'name': 'Jessica Meir', 'craft': 'ISS'}]

# %%
result['people'][0]
# Out:
# {'name': 'Christina Koch', 'craft': 'ISS'}

# %%
result['people'][0]['name']
# Out:
# 'Christina Koch'

# %%
import pandas as pd
df = pd.DataFrame(result)
df
# Out:
#                                             people  number  message
# 0       {'name': 'Christina Koch', 'craft': 'ISS'}       6  success
# 1  {'name': 'Alexander Skvortsov', 'craft': 'ISS'}       6  success
# 2       {'name': 'Luca Parmitano', 'craft': 'ISS'}       6  success
# 3        {'name': 'Andrew Morgan', 'craft': 'ISS'}       6  success
# 4      {'name': 'Oleg Skripochka', 'craft': 'ISS'}       6  success
# 5         {'name': 'Jessica Meir', 'craft': 'ISS'}       6  success

# %%
url    = 'https://api.github.com/events'
response = requests.get(url)
result = response.json()
result
# or in 1 line
# result = requests.get('https://api.github.com/events').json()
# Out:
# [{'id': '11384862822',
#   'type': 'PushEvent',
#   'actor': {'id': 11868577,
#    'login': 'krajcsi',
#    'display_login': 'krajcsi',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/krajcsi',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/11868577?'},
#   'repo': {'id': 40757710,
#    'name': 'cogstat/cogstat',
#    'url': 'https://api.github.com/repos/cogstat/cogstat'},
#   'payload': {'push_id': 4559129392,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'd383fcf4ad4ea80609387c76a0b721c02a1590a9',
#    'before': '354216c8b7396769577a5d0109f15a9833c298d1',
#    'commits': [{'sha': 'd383fcf4ad4ea80609387c76a0b721c02a1590a9',
#      'author': {'email': 'krajcsi@gmail.com', 'name': 'krajcsi'},
#      'message': 'update setup requirements',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/cogstat/cogstat/commits/d383fcf4ad4ea80609387c76a0b721c02a1590a9'}]},
#   'public': True,
# ...

# %%
url    = 'https://api.github.com/events'
response = requests.get(url)
response
# Out:
# <Response [200]>

# %%
response.status_code
# Out:
# 200

# %% [markdown]
# 200
# 200 -- everything went okay, and the result has been returned (if any)
#
# 301 -- the server is redirecting you to a different endpoint. This can happen when a company switches domain names, or an endpoint name is changed.
#
# 401 -- the server thinks you're not authenticated. This happens when you don't send the right credentials to access an API (we'll talk about authentication in a later post).
#
# 400 -- the server thinks you made a bad request. This can happen when you don't send along the right data, among other things.
#
# 403 -- the resource you're trying to access is forbidden -- you don't have the right permissions to see it.
#
# 404 -- the resource you tried to access wasn't found on the server.
#
# http://open-notify.org/Open-Notify-API/ISS-Pass-Times/

# %%
url      = 'https://api.github.com/events'
response = requests.get(url)
result   = response.json()
result
# Out:
# [{'id': '11384910865',
#   'type': 'PushEvent',
#   'actor': {'id': 20096058,
#    'login': 'algitbot',
#    'display_login': 'algitbot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/algitbot',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/20096058?'},
#   'repo': {'id': 19851667,
#    'name': 'alpinelinux/aports',
#    'url': 'https://api.github.com/repos/alpinelinux/aports'},
#   'payload': {'push_id': 4559154002,
#    'size': 2,
#    'distinct_size': 2,
#    'ref': 'refs/heads/master',
#    'head': '1af0a92e2175700980271330d66a4158efed5b9f',
#    'before': 'dae6d52bd4a0588c20bef84aa2d2801b6f4c3541',
#    'commits': [{'sha': '964bd7583b25b7fd39df20cca59f93374b04a60b',
#      'author': {'email': 'thinkabit.ukim@gmail.com', 'name': 'Leo'},
#      'message': 'community/sleuthkit: upgrade to 4.8.0',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/alpinelinux/aports/commits/964bd7583b25b7fd39df20cca59f93374b04a60b'},
# ...

# %%
df = pd.DataFrame(result)
df
# Out:
#              id               type  \
# 0   11384910865          PushEvent
# 1   11384910869          PushEvent
# 2   11384910868          PushEvent
# 3   11384910850          PushEvent
# 4   11384910856          PushEvent
# 5   11384910851  IssueCommentEvent
# 6   11384910849          PushEvent
# 7   11384910843          PushEvent
# 8   11384910841          PushEvent
# 9   11384910830          PushEvent
# 10  11384910833   PullRequestEvent
# 11  11384910834         WatchEvent
# 12  11384910819          PushEvent
# 13  11384910824        CreateEvent
# 14  11384910815          PushEvent
# 15  11384910811          PushEvent
# 16  11384910802          PushEvent
# 17  11384910803        CreateEvent
# 18  11384910787          PushEvent
# 19  11384910794  IssueCommentEvent
# 20  11384910788        CreateEvent
# 21  11384910775          PushEvent
# 22  11384910774          PushEvent
# 23  11384910776          PushEvent
# 24  11384910759          PushEvent
# ...

# %%
df['actor'][0]
# Out:
# {'id': 20096058,
#  'login': 'algitbot',
#  'display_login': 'algitbot',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/algitbot',
#  'avatar_url': 'https://avatars.githubusercontent.com/u/20096058?'}

# %%
df['repo'][0]
# Out:
# {'id': 19851667,
#  'name': 'alpinelinux/aports',
#  'url': 'https://api.github.com/repos/alpinelinux/aports'}

# %%
df['payload'][0]
# Out:
# {'push_id': 4559154002,
#  'size': 2,
#  'distinct_size': 2,
#  'ref': 'refs/heads/master',
#  'head': '1af0a92e2175700980271330d66a4158efed5b9f',
#  'before': 'dae6d52bd4a0588c20bef84aa2d2801b6f4c3541',
#  'commits': [{'sha': '964bd7583b25b7fd39df20cca59f93374b04a60b',
#    'author': {'email': 'thinkabit.ukim@gmail.com', 'name': 'Leo'},
#    'message': 'community/sleuthkit: upgrade to 4.8.0',
#    'distinct': True,
#    'url': 'https://api.github.com/repos/alpinelinux/aports/commits/964bd7583b25b7fd39df20cca59f93374b04a60b'},
#   {'sha': '1af0a92e2175700980271330d66a4158efed5b9f',
#    'author': {'email': 'thinkabit.ukim@gmail.com', 'name': 'Leo'},
#    'message': 'testing/telegram-desktop: upgrade to 1.9.9',
#    'distinct': True,
#    'url': 'https://api.github.com/repos/alpinelinux/aports/commits/1af0a92e2175700980271330d66a4158efed5b9f'}]}

# %% [markdown]
# 1. Turn the nested dictionaries into a data frame with a column for each key
# 2. Assign column names to each column in this new data frame
# 3. Add these new columns to the original data frame
# 4. Drop the column with the nested dictionaries

# %%
def flatten(df):
    for k,v in df['actor'][0].items():
        column_name = 'actor' + '_' + k
        print(column_name)
        print(v)
    df[column_name] = v
    
flatten(df)
df
# Out:
# actor_id
# 20096058
# actor_login
# algitbot
# actor_display_login
# algitbot
# actor_gravatar_id
#
# actor_url
# https://api.github.com/users/algitbot
# actor_avatar_url
# https://avatars.githubusercontent.com/u/20096058?
#              id               type  \
# 0   11384910865          PushEvent
# 1   11384910869          PushEvent
# 2   11384910868          PushEvent
# 3   11384910850          PushEvent
# 4   11384910856          PushEvent
# 5   11384910851  IssueCommentEvent
# 6   11384910849          PushEvent
# 7   11384910843          PushEvent
# 8   11384910841          PushEvent
# 9   11384910830          PushEvent
# 10  11384910833   PullRequestEvent
# 11  11384910834         WatchEvent
# 12  11384910819          PushEvent
# 13  11384910824        CreateEvent
# 14  11384910815          PushEvent
# 15  11384910811          PushEvent
# 16  11384910802          PushEvent
# 17  11384910803        CreateEvent
# 18  11384910787          PushEvent
# ...

# %%
df
# Out:
#              id               type  \
# 0   11384910865          PushEvent
# 1   11384910869          PushEvent
# 2   11384910868          PushEvent
# 3   11384910850          PushEvent
# 4   11384910856          PushEvent
# 5   11384910851  IssueCommentEvent
# 6   11384910849          PushEvent
# 7   11384910843          PushEvent
# 8   11384910841          PushEvent
# 9   11384910830          PushEvent
# 10  11384910833   PullRequestEvent
# 11  11384910834         WatchEvent
# 12  11384910819          PushEvent
# 13  11384910824        CreateEvent
# 14  11384910815          PushEvent
# 15  11384910811          PushEvent
# 16  11384910802          PushEvent
# 17  11384910803        CreateEvent
# 18  11384910787          PushEvent
# 19  11384910794  IssueCommentEvent
# 20  11384910788        CreateEvent
# 21  11384910775          PushEvent
# 22  11384910774          PushEvent
# 23  11384910776          PushEvent
# 24  11384910759          PushEvent
# ...

# %%
from pandas.io.json import json_normalize
results        = response.json()
flattened_data = json_normalize(results)
flattened_data
# Out:
#              id               type  public            created_at  actor.id  \
# 0   11384910865          PushEvent    True  2020-01-29T10:00:49Z  20096058
# 1   11384910869          PushEvent    True  2020-01-29T10:00:49Z  20660506
# 2   11384910868          PushEvent    True  2020-01-29T10:00:49Z  52416426
# 3   11384910850          PushEvent    True  2020-01-29T10:00:49Z    746130
# 4   11384910856          PushEvent    True  2020-01-29T10:00:49Z  20017203
# 5   11384910851  IssueCommentEvent    True  2020-01-29T10:00:49Z  25123234
# 6   11384910849          PushEvent    True  2020-01-29T10:00:49Z  33847963
# 7   11384910843          PushEvent    True  2020-01-29T10:00:49Z   6313774
# 8   11384910841          PushEvent    True  2020-01-29T10:00:49Z  55534963
# 9   11384910830          PushEvent    True  2020-01-29T10:00:49Z   5394232
# 10  11384910833   PullRequestEvent    True  2020-01-29T10:00:49Z  39814207
# ...

# %%
response = requests.get("http://api.open-notify.org/iss-pass.json")
response
# Out:
# <Response [400]>

# %%
#param_ny = {"lat": 40.71, "lon": -74}
param_bcn = {"lat": 41.23, "lon": 2.16}
url       = 'http://api.open-notify.org/iss-pass.json'
response = requests.get(url, params=param_bcn)
response
# Out:
# <Response [200]>

# %%
result = response.json()
result
# Out:
# {'message': 'success',
#  'request': {'altitude': 100,
#   'datetime': 1580294233,
#   'latitude': 41.23,
#   'longitude': 2.16,
#   'passes': 5},
#  'response': [{'duration': 419, 'risetime': 1580304341},
#   {'duration': 651, 'risetime': 1580309992},
#   {'duration': 627, 'risetime': 1580315822},
#   {'duration': 573, 'risetime': 1580321709},
#   {'duration': 610, 'risetime': 1580327556}]}

# %%
timestamp_rise = result['response'][0]['risetime']

# %%
import datetime as dt
import time

# %%
dt.datetime.fromtimestamp(timestamp_rise)
# Out:
# datetime.datetime(2020, 1, 29, 14, 25, 41)

# %%
time.ctime(timestamp_rise)
# Out:
# 'Wed Jan 29 14:25:41 2020'

# %%
http://api.open-notify.org/iss-pass.json?lat=40.71&lon=2.16

# %%
https://www.google.com/search?q=barcelona&rlz=1C5CHFA_enES878ES878&oq=barcelona&aqs=chrome..69i57j0l3j69i60l3j69i65.1566j0j4&sourceid=chrome&ie=UTF-8

# %%
url = 'https://www.google.com/search'
params1 = {'q':'Barcelona'}
response = requests.get(url, params=params1)
response.text
# Out:
# '<!doctype html><html lang="es"><head><meta charset="UTF-8"><meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image"><title>Barcelona - Buscar con Google</title><script nonce="bBypVbe1Qr5YvucIU7EDIQ==">(function(){\ndocument.documentElement.addEventListener("submit",function(b){var a;if(a=b.target){var c=a.getAttribute("data-submitfalse");a="1"==c||"q"==c&&!a.elements.q.value?!0:!1}else a=!1;a&&(b.preventDefault(),b.stopPropagation())},!0);document.documentElement.addEventListener("click",function(b){var a;a:{for(a=b.target;a&&a!=document.documentElement;a=a.parentElement)if("A"==a.tagName){a="1"==a.getAttribute("data-nohref");break a}a=!1}a&&b.preventDefault()},!0);}).call(this);(function(){\nvar a=window.performance;window.start=(new Date).getTime();a:{var b=window;if(a){var c=a.timing;if(c){var d=c.navigationStart,f=c.responseStart;if(f>d&&f<=window.start){window.start=f;b.wsrt=f-d;break a}}a.now&&(b.wsrt=Math.floor(a.now()))}}window.google=win
# ...

# %%
url = 'https://cat-fact.herokuapp.com/facts/random'
response = requests.get(url)
response
# Out:
# <Response [200]>

# %%
response.json()
# Out:
# {'used': False,
#  'source': 'user',
#  'type': 'cat',
#  'deleted': False,
#  '_id': '5d38baf20f1c57001592f14b',
#  'user': '5a9ac18c7478810ea6c06381',
#  'text': "The stationmaster of the Kishi rail station in western Japan until 2015 was a cat named Tama. The calico cat wore a stationmaster's cap and greeted visitors by the ticket gate. After her death, Tama was elevated to the status of a goddess in a Shinto-style funeral.",
#  'createdAt': '2019-07-24T20:09:22.445Z',
#  'updatedAt': '2020-01-02T02:02:48.612Z',
#  '__v': 0,
#  'status': {'verified': True, 'sentCount': 1}}

# %%
result = response.json()
result['text']
# Out:
# "The stationmaster of the Kishi rail station in western Japan until 2015 was a cat named Tama. The calico cat wore a stationmaster's cap and greeted visitors by the ticket gate. After her death, Tama was elevated to the status of a goddess in a Shinto-style funeral."

# %%
url      = 'https://cat-fact.herokuapp.com/facts/random'

for i in range(10):
    response = requests.get(url)
    result   = response.json()
    print(result['text'])
    print('---------------------------')
# Out:
# A cat can jump up to six times its length.
# ---------------------------
# Sir Isaac Newton is not only credited with the laws of gravity but is also credited with inventing the cat flap.
# ---------------------------
# The Bombay cat breed was developed to resemble a miniature panther.
# ---------------------------
# When cats run, their backs contract and extend to give them maximum stride. Their shoulder blades are not attached with bone, but with muscle, and this gives a cat even greater extension and speed.
# ---------------------------
# The domestic cat is the only species able to hold its tail vertically while walking. You can also learn about your cat's present state of mind by observing the posture of his tail.
# ---------------------------
# Evidence suggests domesticated cats have been around since 3600 B.C., 2,000 years before Egypt's pharaohs.
# ---------------------------
# Black cats are less likely to be adopted because of their "appearance".
# ...

# %%
url = 'https://cat-fact.herokuapp.com/facts/random'
params_animal_facts = {'animal_type':'dog'}
response = requests.get(url, params=params_animal_facts)
response
# Out:
# <Response [200]>

# %%
result   = response.json()
print(result['text'])
# Out:
# Dog have superior hearing than humans, capable of hearing sounds at four times the distance.

# %%
def print_animal(animal):
    print(animal)
    params_animal_facts = {'animal_type':animal}
    response = requests.get(url, params=params_animal_facts)
    result   = response.json()
    print(result['text'])
    print('--------------------------------------------------')

url = 'https://cat-fact.herokuapp.com/facts/random'

for i in range(5):
    animal = 'dog'
    print_animal(animal)
    animal = 'cat'
    print_animal(animal)
# Out:
# dog
# If a dog isn’t spayed or neutered, a female dog, her mate and their offspring can product 67,000 dogs in 6 years.
# --------------------------------------------------
# cat
# Most breeds of cat have a noted fondness for settling in high places, or perching. In the wild, a higher place may serve as a concealed site from which to hunt.
# --------------------------------------------------
# dog
# Dogs have about 1,700 taste buds. Humans have approximately 9,000 and cats have around 473.
# --------------------------------------------------
# cat
# Scratching allows a cat to shed the outer layers of her claws, mark her territory, and stretch her body. Rather than discouraging the scratching behavior altogether, try redirecting your cat to a few scratching posts placed strategically around your home.
# --------------------------------------------------
# dog
# It was recently discovered that dogs do see in color, just not as vivid as we see.
# ...

# %%
url = 'https://cat-fact.herokuapp.com/facts/random'
parameters_animal = 'horse,snail'
parameters_amount = 20
parameters_dict = {'animal_typppe':parameters_animal, 'amount':parameters_amount}
response = requests.get(url, parameters_dict)
response
# Out:
# <Response [200]>

# %%
result   = response.json()
type(result)
result
for fact in result:
    print(fact['text'])
    print('------------------------')
# Out:
# Kittens who are taken along on short, trouble-free car trips to town tend to make good passengers when they get older. They get used to the sounds and motions of traveling and make less connection between the car and the visits to the vet.
# ------------------------
# Female cats are "polyestrous," which means they may have many heat periods over the course of a year. A heat period lasts about 4 to 7 days if the female is bred; if she is not, the heat period lasts longer and recurs at regular intervals.
# ------------------------
# The little tufts of hair in a cat’s ear that help keep out dirt direct sounds into the ear, and insulate the ears are called "ear furnishings."
# ------------------------
# When your cats rubs up against you, she is actually marking you as "hers" with her scent. If your cat pushes his face against your head, it is a sign of acceptance and affection.
# ------------------------
# ...

# %%
#print(json.dumps(response_swapi_json, indent=4))
#respons.headers

# %%
import json
url = 'http://swapi.co/api/planets/1/'
response_swapi = requests.get(url)
response_swapi_json = response_swapi.json()
print(json.dumps(response_swapi_json, indent=4))
# Out:
# {
#     "name": "Tatooine",
#     "rotation_period": "23",
#     "orbital_period": "304",
#     "diameter": "10465",
#     "climate": "arid",
#     "gravity": "1 standard",
#     "terrain": "desert",
#     "surface_water": "1",
#     "population": "200000",
#     "residents": [
#         "https://swapi.co/api/people/1/",
#         "https://swapi.co/api/people/2/",
#         "https://swapi.co/api/people/4/",
#         "https://swapi.co/api/people/6/",
#         "https://swapi.co/api/people/7/",
#         "https://swapi.co/api/people/8/",
#         "https://swapi.co/api/people/9/",
#         "https://swapi.co/api/people/11/",
#         "https://swapi.co/api/people/43/",
#         "https://swapi.co/api/people/62/"
#     ],
#     "films": [
#         "https://swapi.co/api/films/5/",
#         "https://swapi.co/api/films/4/",
#         "https://swapi.co/api/films/6/",
#         "https://swapi.co/api/films/3/",
#         "https://swapi.co/api/films/1/"
#     ],
# ...

# %%
url2 = response_swapi_json['films'][0]
url2
# Out:
# 'https://swapi.co/api/films/5/'

# %%
response_films = requests.get(url2)
response_films
# Out:
# <Response [200]>

# %%
response_films.headers
# Out:
# {'Date': 'Wed, 29 Jan 2020 13:29:15 GMT', 'Content-Type': 'application/json', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'Set-Cookie': '__cfduid=dd96c941e16790855e2fb123c23a7d45f1580304554; expires=Fri, 28-Feb-20 13:29:14 GMT; path=/; domain=.swapi.co; HttpOnly; SameSite=Lax; Secure', 'Etag': 'W/"bc28b26d01b8dac2e52ad696a6c53bb9"', 'Allow': 'GET, HEAD, OPTIONS', 'X-Frame-Options': 'SAMEORIGIN', 'Vary': 'Accept, Cookie', 'Via': '1.1 vegur', 'CF-Cache-Status': 'DYNAMIC', 'Expect-CT': 'max-age=604800, report-uri="https://report-uri.cloudflare.com/cdn-cgi/beacon/expect-ct"', 'Server': 'cloudflare', 'CF-RAY': '55cb8dca3cd0bd63-CDG', 'Content-Encoding': 'gzip'}

# %%
response_films.json()
# Out:
# {'title': 'Attack of the Clones',
#  'episode_id': 2,
#  'opening_crawl': 'There is unrest in the Galactic\r\nSenate. Several thousand solar\r\nsystems have declared their\r\nintentions to leave the Republic.\r\n\r\nThis separatist movement,\r\nunder the leadership of the\r\nmysterious Count Dooku, has\r\nmade it difficult for the limited\r\nnumber of Jedi Knights to maintain \r\npeace and order in the galaxy.\r\n\r\nSenator Amidala, the former\r\nQueen of Naboo, is returning\r\nto the Galactic Senate to vote\r\non the critical issue of creating\r\nan ARMY OF THE REPUBLIC\r\nto assist the overwhelmed\r\nJedi....',
#  'director': 'George Lucas',
#  'producer': 'Rick McCallum',
#  'release_date': '2002-05-16',
#  'characters': ['https://swapi.co/api/people/2/',
#   'https://swapi.co/api/people/3/',
#   'https://swapi.co/api/people/6/',
#   'https://swapi.co/api/people/7/',
#   'https://swapi.co/api/people/10/',
#   'https://swapi.co/api/people/11/',
# ...

# %%
url3 = 'https://swapi.co/api/vehicles/44/'
requests.get(url3).json()
# Out:
# {'name': 'Zephyr-G swoop bike',
#  'model': 'Zephyr-G swoop bike',
#  'manufacturer': 'Mobquet Swoops and Speeders',
#  'cost_in_credits': '5750',
#  'length': '3.68',
#  'max_atmosphering_speed': '350',
#  'crew': '1',
#  'passengers': '1',
#  'cargo_capacity': '200',
#  'consumables': 'none',
#  'vehicle_class': 'repulsorcraft',
#  'pilots': ['https://swapi.co/api/people/11/'],
#  'films': ['https://swapi.co/api/films/5/'],
#  'created': '2014-12-20T16:24:16.026000Z',
#  'edited': '2014-12-22T18:21:16.117652Z',
#  'url': 'https://swapi.co/api/vehicles/44/'}

# %%
url3 = 'https://swapi.co/api/vehicles/'
r = requests.get(url3).json()
len(r)

#pd.DataFrame(requests.get(url3).json())
# Out:
# 4

# %%
r
# Out:
# {'count': 39,
#  'next': 'https://swapi.co/api/vehicles/?page=2',
#  'previous': None,
#  'results': [{'name': 'Sand Crawler',
#    'model': 'Digger Crawler',
#    'manufacturer': 'Corellia Mining Corporation',
#    'cost_in_credits': '150000',
#    'length': '36.8',
#    'max_atmosphering_speed': '30',
#    'crew': '46',
#    'passengers': '30',
#    'cargo_capacity': '50000',
#    'consumables': '2 months',
#    'vehicle_class': 'wheeled',
#    'pilots': [],
#    'films': ['https://swapi.co/api/films/5/', 'https://swapi.co/api/films/1/'],
#    'created': '2014-12-10T15:36:25.724000Z',
#    'edited': '2014-12-22T18:21:15.523587Z',
#    'url': 'https://swapi.co/api/vehicles/4/'},
#   {'name': 'T-16 skyhopper',
#    'model': 'T-16 skyhopper',
#    'manufacturer': 'Incom Corporation',
#    'cost_in_credits': '14500',
#    'length': '10.4',
#    'max_atmosphering_speed': '1200',
#    'crew': '1',
#    'passengers': '1',
#    'cargo_capacity': '50',
#    'consumables': '0',
# ...

# %%
vehicles = r['results']

# %%
len(vehicles)
# Out:
# 10

# %%
vehicles
# Out:
# [{'name': 'Sand Crawler',
#   'model': 'Digger Crawler',
#   'manufacturer': 'Corellia Mining Corporation',
#   'cost_in_credits': '150000',
#   'length': '36.8',
#   'max_atmosphering_speed': '30',
#   'crew': '46',
#   'passengers': '30',
#   'cargo_capacity': '50000',
#   'consumables': '2 months',
#   'vehicle_class': 'wheeled',
#   'pilots': [],
#   'films': ['https://swapi.co/api/films/5/', 'https://swapi.co/api/films/1/'],
#   'created': '2014-12-10T15:36:25.724000Z',
#   'edited': '2014-12-22T18:21:15.523587Z',
#   'url': 'https://swapi.co/api/vehicles/4/'},
#  {'name': 'T-16 skyhopper',
#   'model': 'T-16 skyhopper',
#   'manufacturer': 'Incom Corporation',
#   'cost_in_credits': '14500',
#   'length': '10.4',
#   'max_atmosphering_speed': '1200',
#   'crew': '1',
#   'passengers': '1',
#   'cargo_capacity': '50',
#   'consumables': '0',
#   'vehicle_class': 'repulsorcraft',
#   'pilots': [],
#   'films': ['https://swapi.co/api/films/1/'],
# ...

# %%
for vehicle in vehicles:
    print(vehicle['name'])
# Out:
# Sand Crawler
# T-16 skyhopper
# X-34 landspeeder
# TIE/LN starfighter
# Snowspeeder
# TIE bomber
# AT-AT
# AT-ST
# Storm IV Twin-Pod cloud car
# Sail barge

# %%
key1 = 'AIzaSyAhQ0sPyYIxdsxrVOOmDONOoaxoXqGUiT4'
url = 'https://maps.googleapis.com/maps/api/geocode/json'
params1 = {'address':'1600+Amphitheatre+Parkway,+Mountain+View,+CA',
            'key':key1}
response = requests.get(url, params=params1)
response
# Out:
# <Response [200]>

# %%
r = response.json()

# %%
print(json.dumps(r, indent=4))
# Out:
# {
#     "results": [
#         {
#             "address_components": [
#                 {
#                     "long_name": "1600",
#                     "short_name": "1600",
#                     "types": [
#                         "street_number"
#                     ]
#                 },
#                 {
#                     "long_name": "Amphitheatre Parkway",
#                     "short_name": "Amphitheatre Pkwy",
#                     "types": [
#                         "route"
#                     ]
#                 },
#                 {
#                     "long_name": "Mountain View",
#                     "short_name": "Mountain View",
#                     "types": [
#                         "locality",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Santa Clara County",
#                     "short_name": "Santa Clara County",
#                     "types": [
# ...

# %%
lat = r['results'][0]['geometry']['location']['lat']
lon = r['results'][0]['geometry']['location']['lng']

# %%
def from_address_to_coords(adress):
    key1 = 'AIzaSyAhQ0sPyYIxdsxrVOOmDONOoaxoXqGUiT4'
    url = 'https://maps.googleapis.com/maps/api/geocode/json'
    params1 = {'address':address,
                'key':key1}
    response = requests.get(url, params=params1) 
    print('The lattitude and longitude of adress', address, ' is')
    print(lat,lon)
    return (lat,lon)

address = '1600+Amphitheatre+Parkway,+Mountain+View,+CA'
lat,lon = from_address_to_coords(address)
# Out:
# The lattitude and longitude of adress 1600+Amphitheatre+Parkway,+Mountain+View,+CA  is
# 37.4222562 -122.0847626

# %%
def from_address_to_coords_question():
    address = input('What address?')
    print(address)

    key1 = 'AIzaSyAhQ0sPyYIxdsxrVOOmDONOoaxoXqGUiT4'
    url = 'https://maps.googleapis.com/maps/api/geocode/json'
    params1 = {'address':address,
                'key':key1}
    # todo check if request is error free
    r   = requests.get(url, params=params1).json()
    lat = r['results'][0]['geometry']['location']['lat']
    lon = r['results'][0]['geometry']['location']['lng']  
    
    print('The lattitude and longitude of adress', address, ' is')
    print(lat,lon)
    return (lat,lon)

from_address_to_coords_question()
