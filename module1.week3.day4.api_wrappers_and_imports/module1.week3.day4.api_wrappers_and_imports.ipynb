# %%
import forecastio as forec

# %%
api_key = "0bfa820c54f7c641b1ca1efde7ed506e"
lat = 41.39
lng = 2.17
f = forec.load_forecast(api_key, lat, lng)

# %%
type(f)
# Out:
# forecastio.models.Forecast

# %%
f.hourly().summary
# Out:
# 'Mostly cloudy throughout the day.'

# %%
f.daily().summary
# Out:
# 'No precipitation throughout the week.'

# %%
f.currently().summary
# Out:
# 'Overcast'

# %%
from coord_transformations import from_address_to_coords 
# import all:
#from coord_transformations import *
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-7-9de95f658bbd> in <module>
# ----> 1 from coord_transformations import from_address_to_coords
#       2 # import all:
#       3 #from coord_transformations import *
#
# ImportError: cannot import name 'from_address_to_coords' from 'coord_transformations' (/Users/tjerk/Documents/codealongs/api/coord_transformations.py)

# %%
address = 'Dam 1,Amsterdam'
(lat,lon) = from_address_to_coords(address)

# %%
from from_coords_to_forecast import coords_to_forecast

# %%
coords_to_forecast(True)

# %%
from from_coords_to_forecast3 import coords_to_forecast

# %%
lat_lon_tuple = (52.3,4.8)
coords_to_forecast(True, lat_lon_tuple)

# %%
coords_to_forecast(True, (10,10))

# %%
del coords_to_forecast

# %%
from from_coords_to_forecast3 import coords_to_forecast

address = 'Dam 1,Amsterdam'
(lat,lon) = from_address_to_coords(address)
coords_to_forecast(True, (lat,lon))

#this also works
#lat_lon_tuple = from_address_to_coords(address)
#coords_to_forecast(True, lat_lon_tuple)

# %%
from address_to_weather import from_address_to_weather

# %%
from_address_to_weather('the whitehouse, washington')

# %%
from_address_to_weather('the greenhouse, Amsterdam')

# %%
from_address_to_weather('North pole')

# %%
from_address_to_weather('Miami')

# %%
from_address_to_weather('Cairo,Egypt')

# %%
from_address_to_weather('Buenos aires')

# %%
from from_coords_to_forecast import coords_to_forecast
coords_to_forecast(True)

# %%
from kevin import h
h.hi()
# Out:
# hi kevin

# %%
from kevin.kevin2.h import hi
hi()
# Out:
# hi kevin

# %%
#todo add kevin folder structure

# %%
from stackapi import StackAPI
SITE = StackAPI('stackoverflow')

# %%
type(SITE)
# Out:
# stackapi.stackapi.StackAPI

# %%
comments = SITE.fetch('comments')
comments
# Out:
# {'backoff': 0,
#  'has_more': True,
#  'page': 5,
#  'quota_max': 300,
#  'quota_remaining': 300,
#  'total': 0,
#  'items': [{'owner': {'reputation': 127,
#     'user_id': 5809078,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/0b3bc397d5f3bd699e6f5d62e56fd468?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'Paramatma Sharan',
#     'link': 'https://stackoverflow.com/users/5809078/paramatma-sharan'},
#    'edited': False,
#    'score': 0,
#    'creation_date': 1580380423,
#    'post_id': 50580240,
#    'comment_id': 106081744},
#   {'owner': {'reputation': 544,
#     'user_id': 5616255,
#     'user_type': 'registered',
#     'profile_image': 'https://i.stack.imgur.com/frl7l.jpg?s=128&g=1',
#     'display_name': 'Bojan P.',
#     'link': 'https://stackoverflow.com/users/5616255/bojan-p'},
#    'edited': False,
#    'score': 0,
#    'creation_date': 1580380422,
#    'post_id': 59983789,
#    'comment_id': 106081743},
# ...

# %%
fromdate_30dec_timestamp  = 1577692800
todate_30jan_timestamp    = 1580371200
questions = SITE.fetch('questions', 
    fromdate=fromdate_30dec_timestamp, 
    todate=todate_30jan_timestamp,
    min=20, tagged='python', sort='votes')

# %%
questions
# Out:
# {'backoff': 0,
#  'has_more': False,
#  'page': 1,
#  'quota_max': 300,
#  'quota_remaining': 300,
#  'total': 0,
#  'items': [{'tags': ['python', 'function', 'return', 'generator', 'yield'],
#    'owner': {'reputation': 3522,
#     'user_id': 253266,
#     'user_type': 'registered',
#     'accept_rate': 63,
#     'profile_image': 'https://www.gravatar.com/avatar/60f8be1907b4d9c4d1c4a6a4b0556bc7?s=128&d=identicon&r=PG',
#     'display_name': 'hyankov',
#     'link': 'https://stackoverflow.com/users/253266/hyankov'},
#    'is_answered': True,
#    'view_count': 1620,
#    'accepted_answer_id': 59600668,
#    'answer_count': 5,
#    'score': 29,
#    'last_activity_date': 1578848356,
#    'creation_date': 1578187008,
#    'last_edit_date': 1578848356,
#    'question_id': 59596261,
#    'link': 'https://stackoverflow.com/questions/59596261/return-or-yield-from-a-function-that-calls-a-generator',
#    'title': 'Return or yield from a function that calls a generator?'},
# ...
