# %%
import pandas as pd

# %%
ufos = pd.read_csv('scrubbed.csv', low_memory=False)

# %%
ufos.head()
# Out:
#            datetime                  city state country     shape  \
# 0  10/10/1949 20:30            san marcos    tx      us  cylinder
# 1  10/10/1949 21:00          lackland afb    tx     NaN     light
# 2  10/10/1955 17:00  chester (uk/england)   NaN      gb    circle
# 3  10/10/1956 21:00                  edna    tx      us    circle
# 4  10/10/1960 20:00               kaneohe    hi      us     light
#
#   duration (seconds) duration (hours/min)  \
# 0               2700           45 minutes
# 1               7200              1-2 hrs
# 2                 20           20 seconds
# 3                 20             1/2 hour
# 4                900           15 minutes
#
#                                             comments date posted    latitude  \
# 0  This event took place in early fall around 194...   4/27/2004  29.8830556
# 1  1949 Lackland AFB&#44 TX.  Lights racing acros...  12/16/2005    29.38421
# ...

# %%
ufos.dtypes
# Out:
# datetime                 object
# city                     object
# state                    object
# country                  object
# shape                    object
# duration (seconds)       object
# duration (hours/min)     object
# comments                 object
# date posted              object
# latitude                 object
# longitude               float64
# dtype: object

# %%
ufos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80332 entries, 0 to 80331
# Data columns (total 11 columns):
# datetime                80332 non-null object
# city                    80332 non-null object
# state                   74535 non-null object
# country                 70662 non-null object
# shape                   78400 non-null object
# duration (seconds)      80332 non-null object
# duration (hours/min)    80332 non-null object
# comments                80317 non-null object
# date posted             80332 non-null object
# latitude                80332 non-null object
# longitude               80332 non-null float64
# dtypes: float64(1), object(10)
# memory usage: 6.7+ MB

# %%
ufos.columns
# Out:
# Index(['datetime', 'city', 'state', 'country', 'shape', 'duration (seconds)',
#        'duration (hours/min)', 'comments', 'date posted', 'latitude',
#        'longitude '],
#       dtype='object')

# %%
ufos.iloc[:, :]
# Out:
#                datetime                  city state country     shape  \
# 0      10/10/1949 20:30            san marcos    tx      us  cylinder
# 1      10/10/1949 21:00          lackland afb    tx     NaN     light
# 2      10/10/1955 17:00  chester (uk/england)   NaN      gb    circle
# 3      10/10/1956 21:00                  edna    tx      us    circle
# 4      10/10/1960 20:00               kaneohe    hi      us     light
# ...                 ...                   ...   ...     ...       ...
# 80327    9/9/2013 21:15             nashville    tn      us     light
# 80328    9/9/2013 22:00                 boise    id      us    circle
# 80329    9/9/2013 22:00                  napa    ca      us     other
# 80330    9/9/2013 22:20                vienna    va      us    circle
# 80331    9/9/2013 23:00                edmond    ok      us     cigar
#
#       duration (seconds) duration (hours/min)  \
# 0                   2700           45 minutes
# ...

# %%
ufos.loc[0, 'datetime']
# Out:
# 0        10/10/1949 20:30
# 1        10/10/1949 21:00
# 2        10/10/1955 17:00
# 3        10/10/1956 21:00
# 4        10/10/1960 20:00
#                ...
# 80327      9/9/2013 21:15
# 80328      9/9/2013 22:00
# 80329      9/9/2013 22:00
# 80330      9/9/2013 22:20
# 80331      9/9/2013 23:00
# Name: datetime, Length: 80332, dtype: object

# %%
ufos.loc[0, :]
# Out:
# datetime                                                 10/10/1949 20:30
# city                                                           san marcos
# state                                                                  tx
# country                                                                us
# shape                                                            cylinder
# duration (seconds)                                                   2700
# duration (hours/min)                                           45 minutes
# comments                This event took place in early fall around 194...
# date posted                                                     4/27/2004
# latitude                                                       29.8830556
# longitude                                                        -97.9411
# Name: 0, dtype: object

# %%
ufos.loc[0, ['city', 'state', 'country', 'shape']]
# Out:
# city       san marcos
# state              tx
# country            us
# shape        cylinder
# Name: 0, dtype: object

# %%
ufos.loc[:, ['city','shape']]
# Out:
#                        city     shape
# 0                san marcos  cylinder
# 1              lackland afb     light
# 2      chester (uk/england)    circle
# 3                      edna    circle
# 4                   kaneohe     light
# ...                     ...       ...
# 80327             nashville     light
# 80328                 boise    circle
# 80329                  napa     other
# 80330                vienna    circle
# 80331                edmond     cigar
#
# [80332 rows x 2 columns]

# %%
columns = ufos.columns[1:5]
list(columns)
# Out:
# ['city', 'state', 'country', 'shape']

# %%
ufos.loc[:, columns]
# Out:
#                        city state country     shape
# 0                san marcos    tx      us  cylinder
# 1              lackland afb    tx     NaN     light
# 2      chester (uk/england)   NaN      gb    circle
# 3                      edna    tx      us    circle
# 4                   kaneohe    hi      us     light
# ...                     ...   ...     ...       ...
# 80327             nashville    tn      us     light
# 80328                 boise    id      us    circle
# 80329                  napa    ca      us     other
# 80330                vienna    va      us    circle
# 80331                edmond    ok      us     cigar
#
# [80332 rows x 4 columns]

# %%
ufos.loc[:, ufos.columns[1:5]]
# Out:
#                        city state country     shape
# 0                san marcos    tx      us  cylinder
# 1              lackland afb    tx     NaN     light
# 2      chester (uk/england)   NaN      gb    circle
# 3                      edna    tx      us    circle
# 4                   kaneohe    hi      us     light
# ...                     ...   ...     ...       ...
# 80327             nashville    tn      us     light
# 80328                 boise    id      us    circle
# 80329                  napa    ca      us     other
# 80330                vienna    va      us    circle
# 80331                edmond    ok      us     cigar
#
# [80332 rows x 4 columns]

# %%
ufos.head()
# Out:
#            datetime                  city state country     shape  \
# 0  10/10/1949 20:30            san marcos    tx      us  cylinder
# 1  10/10/1949 21:00          lackland afb    tx     NaN     light
# 2  10/10/1955 17:00  chester (uk/england)   NaN      gb    circle
# 3  10/10/1956 21:00                  edna    tx      us    circle
# 4  10/10/1960 20:00               kaneohe    hi      us     light
#
#   duration (seconds) duration (hours/min)  \
# 0               2700           45 minutes
# 1               7200              1-2 hrs
# 2                 20           20 seconds
# 3                 20             1/2 hour
# 4                900           15 minutes
#
#                                             comments date posted    latitude  \
# 0  This event took place in early fall around 194...   4/27/2004  29.8830556
# 1  1949 Lackland AFB&#44 TX.  Lights racing acros...  12/16/2005    29.38421
# ...

# %%
ufos.astype({'datetime': 'datetime64[ns]'})
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.7/site-packages/pandas/core/arrays/datetimes.py in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object)
#    1978         try:
# -> 1979             values, tz_parsed = conversion.datetime_to_datetime64(data)
#    1980             # If tzaware, these values represent unix timestamps, so we
#
# pandas/_libs/tslibs/conversion.pyx in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-32-0bfc698e31e2> in <module>
# ----> 1 ufos.astype({'datetime': 'datetime64[ns]'})
#
# ...

# %%
ufos.head()
# Out:
#            datetime                  city state country     shape  \
# 0  10/10/1949 20:30            san marcos    tx      us  cylinder
# 1  10/10/1949 21:00          lackland afb    tx     NaN     light
# 2  10/10/1955 17:00  chester (uk/england)   NaN      gb    circle
# 3  10/10/1956 21:00                  edna    tx      us    circle
# 4  10/10/1960 20:00               kaneohe    hi      us     light
#
#   duration (seconds) duration (hours/min)  \
# 0               2700           45 minutes
# 1               7200              1-2 hrs
# 2                 20           20 seconds
# 3                 20             1/2 hour
# 4                900           15 minutes
#
#                                             comments date posted    latitude  \
# 0  This event took place in early fall around 194...   4/27/2004  29.8830556
# 1  1949 Lackland AFB&#44 TX.  Lights racing acros...  12/16/2005    29.38421
# ...

# %%
ufos.rename(columns={'date posted': 'date_posted'}, inplace=True)

# %%
ufos.head()
# Out:
#            datetime                  city state country     shape  \
# 0  10/10/1949 20:30            san marcos    tx      us  cylinder
# 1  10/10/1949 21:00          lackland afb    tx     NaN     light
# 2  10/10/1955 17:00  chester (uk/england)   NaN      gb    circle
# 3  10/10/1956 21:00                  edna    tx      us    circle
# 4  10/10/1960 20:00               kaneohe    hi      us     light
#
#   duration (seconds) duration (hours/min)  \
# 0               2700           45 minutes
# 1               7200              1-2 hrs
# 2                 20           20 seconds
# 3                 20             1/2 hour
# 4                900           15 minutes
#
#                                             comments date_posted    latitude  \
# 0  This event took place in early fall around 194...   4/27/2004  29.8830556
# 1  1949 Lackland AFB&#44 TX.  Lights racing acros...  12/16/2005    29.38421
# ...

# %%
ufos['date posted']
# Out:
# 0         4/27/2004
# 1        12/16/2005
# 2         1/21/2008
# 3         1/17/2004
# 4         1/22/2004
#             ...
# 80327     9/30/2013
# 80328     9/30/2013
# 80329     9/30/2013
# 80330     9/30/2013
# 80331     9/30/2013
# Name: date posted, Length: 80332, dtype: object

# %%
ufos.astype({'datetime': 'str'}, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-45-bb1f3f760710> in <module>
# ----> 1 ufos.astype({'datetime': 'str'}, inplace=True)
#
# /usr/local/lib/python3.7/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors, **kwargs)
#    5863                     results.append(
#    5864                         col.astype(
# -> 5865                             dtype=dtype[col_name], copy=copy, errors=errors, **kwargs
#    5866                         )
#    5867                     )
#
# /usr/local/lib/python3.7/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors, **kwargs)
#    5880             # else, only a single dtype is given
#    5881             new_data = self._data.astype(
# -> 5882                 dtype=dtype, copy=copy, errors=errors, **kwargs
#    5883             )
# ...

# %%
ufos.datetime = ufos.astype({'datetime': 'str'})

# %%
ufos.datetime = ufos.datetime.astype(str)

# %%
'24:' in list(ufos.datetime.unique())
# Out:
# False

# %%
list(ufos.datetime.unique())
# Out:
# ['10/10/1949 20:30',
#  '10/10/1949 21:00',
#  '10/10/1955 17:00',
#  '10/10/1956 21:00',
#  '10/10/1960 20:00',
#  '10/10/1961 19:00',
#  '10/10/1965 21:00',
#  '10/10/1965 23:45',
#  '10/10/1966 20:00',
#  '10/10/1966 21:00',
#  '10/10/1968 13:00',
#  '10/10/1968 19:00',
#  '10/10/1970 16:00',
#  '10/10/1970 19:00',
#  '10/10/1971 21:00',
#  '10/10/1972 19:00',
#  '10/10/1972 22:30',
#  '10/10/1973 19:00',
#  '10/10/1973 23:00',
#  '10/10/1974 19:30',
#  '10/10/1974 21:30',
#  '10/10/1974 23:00',
#  '10/10/1975 17:00',
#  '10/10/1976 20:30',
#  '10/10/1976 22:00',
#  '10/10/1977 12:00',
#  '10/10/1977 22:00',
#  '10/10/1978 02:00',
#  '10/10/1979 00:00',
#  '10/10/1979 22:00',
#  '10/10/1980 19:00',
#  '10/10/1980 22:00',
#  '10/10/1980 23:30',
#  '10/10/1982 07:00',
#  '10/10/1984 05:00',
#  '10/10/1984 12:00',
#  '10/10/1984 22:00',
#  '10/10/1985 20:25',
#  '10/10/1986 20:00',
#  '10/10/1988 18:00',
#  '10/10/1988 21:00',
#  '10/10/1988 22:00',
#  '10/10/1988 22:45',
# ...

# %%
ufos['bad_hour'] = ufos.datetime.apply(lambda x: '24:' in x)

# %%
ufos['bad_hour'] == True
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 80327    False
# 80328    False
# 80329    False
# 80330    False
# 80331    False
# Name: bad_hour, Length: 80332, dtype: bool

# %%
ufos.datetime
# Out:
# 0        10/10/1949 20:30
# 1        10/10/1949 21:00
# 2        10/10/1955 17:00
# 3        10/10/1956 21:00
# 4        10/10/1960 20:00
#                ...
# 80327      9/9/2013 21:15
# 80328      9/9/2013 22:00
# 80329      9/9/2013 22:00
# 80330      9/9/2013 22:20
# 80331      9/9/2013 23:00
# Name: datetime, Length: 80332, dtype: object

# %%
ufos[ufos['bad_hour'] == True]
# Out:
#                datetime                              city state country  \
# 388    10/11/2006 24:00                              rome    ny      us
# 693     10/1/2001 24:00  chulucanas-piura la vieja (peru)   NaN     NaN
# 962     10/1/2012 24:00                              novi    mi      us
# 1067   10/12/2003 24:00              salatiga (indonesia)   NaN     NaN
# 1221   10/12/2013 24:00                        cincinnati    oh      us
# ...                 ...                               ...   ...     ...
# 79136    9/4/2005 24:00                         boonville    nc      us
# 79137    9/4/2005 24:00                     redondo beach    ca      us
# 79740    9/7/2002 24:00                        portsmouth    oh      us
# 79759    9/7/2004 24:00                          montrose    co      us
# 79942    9/8/2003 24:00                      cedar rapids    ia      us
#
#           shape duration (seconds) duration (hours/min)  \
# ...

# %%
ufos['datetime'] = ufos['datetime'].apply(lambda x: x.replace('24:', '00:'))

# %%
ufos[ufos['bad_hour'] == True]
# Out:
#         datetime                              city state country     shape  \
# 388   2006-10-11                              rome    ny      us      oval
# 693   2001-10-01  chulucanas-piura la vieja (peru)   NaN     NaN     other
# 962   2012-10-01                              novi    mi      us  triangle
# 1067  2003-10-12              salatiga (indonesia)   NaN     NaN      disk
# 1221  2013-10-12                        cincinnati    oh      us  fireball
# ...          ...                               ...   ...     ...       ...
# 79136 2005-09-04                         boonville    nc      us     cigar
# 79137 2005-09-04                     redondo beach    ca      us  triangle
# 79740 2002-09-07                        portsmouth    oh      us  changing
# 79759 2004-09-07                          montrose    co      us   unknown
# 79942 2003-09-08                      cedar rapids    ia      us  changing
#
#       duration (seconds) duration (hours/min)  \
# ...

# %%
ufos.datetime = ufos.datetime.astype('datetime64[ns]')

# %%
ufos.datetime[ufos.datetime]
# Out:
# 0       1949-10-10 20:30:00
# 1       1949-10-10 21:00:00
# 2       1955-10-10 17:00:00
# 3       1956-10-10 21:00:00
# 4       1960-10-10 20:00:00
#                 ...
# 80327   2013-09-09 21:15:00
# 80328   2013-09-09 22:00:00
# 80329   2013-09-09 22:00:00
# 80330   2013-09-09 22:20:00
# 80331   2013-09-09 23:00:00
# Name: datetime, Length: 80332, dtype: datetime64[ns]

# %%
ufos.isna()
# Out:
#        datetime   city  state  country  shape  duration (seconds)  \
# 0         False  False  False    False  False               False
# 1         False  False  False     True  False               False
# 2         False  False   True    False  False               False
# 3         False  False  False    False  False               False
# 4         False  False  False    False  False               False
# ...         ...    ...    ...      ...    ...                 ...
# 80327     False  False  False    False  False               False
# 80328     False  False  False    False  False               False
# 80329     False  False  False    False  False               False
# 80330     False  False  False    False  False               False
# 80331     False  False  False    False  False               False
#
#        duration (hours/min)  comments  date_posted  latitude  longitude   \
# 0                     False     False        False     False       False
# ...

# %%
ufos.isna().sum()
# Out:
# datetime                   0
# city                       0
# state                   5797
# country                 9670
# shape                   1932
# duration (seconds)         0
# duration (hours/min)       0
# comments                  15
# date_posted                0
# latitude                   0
# longitude                  0
# bad_hour                   0
# dtype: int64

# %%
ufos.isnull().sum()
# Out:
# datetime                   0
# city                       0
# state                   5797
# country                 9670
# shape                   1932
# duration (seconds)         0
# duration (hours/min)       0
# comments                  15
# date_posted                0
# latitude                   0
# longitude                  0
# bad_hour                   0
# dtype: int64

# %%
ufos.fillna(0, inplace=True)

# %%
ufos.isna().sum()
# Out:
# datetime                0
# city                    0
# state                   0
# country                 0
# shape                   0
# duration (seconds)      0
# duration (hours/min)    0
# comments                0
# date_posted             0
# latitude                0
# longitude               0
# bad_hour                0
# dtype: int64

# %%
ufos[~ufos.isna()]
# Out:
#                  datetime                  city state country     shape  \
# 0     1949-10-10 20:30:00            san marcos    tx      us  cylinder
# 1     1949-10-10 21:00:00          lackland afb    tx       0     light
# 2     1955-10-10 17:00:00  chester (uk/england)     0      gb    circle
# 3     1956-10-10 21:00:00                  edna    tx      us    circle
# 4     1960-10-10 20:00:00               kaneohe    hi      us     light
# ...                   ...                   ...   ...     ...       ...
# 80327 2013-09-09 21:15:00             nashville    tn      us     light
# 80328 2013-09-09 22:00:00                 boise    id      us    circle
# 80329 2013-09-09 22:00:00                  napa    ca      us     other
# 80330 2013-09-09 22:20:00                vienna    va      us    circle
# 80331 2013-09-09 23:00:00                edmond    ok      us     cigar
#
#       duration (seconds) duration (hours/min)  \
# 0                   2700           45 minutes
# ...

# %%
ufos.state.value_counts()
# Out:
# ca    9655
# 0     5797
# wa    4268
# fl    4200
# tx    3677
#       ...
# nf      25
# nt      20
# pe      17
# yt      13
# yk       7
# Name: state, Length: 68, dtype: int64

# %%
ufos.groupby('state').count()
# Out:
#        datetime  city  country  shape  duration (seconds)  \
# state
# 0          5797  5797     5797   5797                5797
# ab          333   333      333    333                 333
# ak          354   354      354    354                 354
# al          691   691      691    691                 691
# ar          666   666      666    666                 666
# ...         ...   ...      ...    ...                 ...
# wi         1333  1333     1333   1333                1333
# wv          486   486      486    486                 486
# wy          205   205      205    205                 205
# yk            7     7        7      7                   7
# yt           13    13       13     13                  13
#
#        duration (hours/min)  comments  date_posted  latitude  longitude   \
# state
# 0                      5797      5797         5797      5797        5797
# ab                      333       333          333       333         333
# ...

# %%
ufos.groupby('state').count().iloc[:, 0]
# Out:
# state
# 0     5797
# ab     333
# ak     354
# al     691
# ar     666
#       ...
# wi    1333
# wv     486
# wy     205
# yk       7
# yt      13
# Name: datetime, Length: 68, dtype: int64

# %%
ufos.groupby(['state', 'country']).mean()
# Out:
#                longitude   bad_hour
# state country
# 0     0         17.439098  0.019349
#       au       143.370031  0.011364
#       ca       -87.594444  0.000000
#       de        10.063808  0.028571
#       gb        -1.673622  0.020602
# ...                   ...       ...
# yk    ca      -131.925000  0.000000
# yt    0       -108.355964  0.000000
#       au       152.908936  0.000000
#       ca      -132.480000  0.000000
#       gb        -3.100000  0.000000
#
# [157 rows x 2 columns]

# %%
ufos[(ufos['state']=='tx') & (ufos['shape']=='circle')]
# Out:
#                  datetime          city state country   shape  \
# 3     1956-10-10 21:00:00          edna    tx      us  circle
# 36    1984-10-10 05:00:00       houston    tx      us  circle
# 798   2006-10-01 01:30:00        irving    tx      us  circle
# 1046  2002-10-12 11:00:00      winfield    tx      us  circle
# 1449  2013-10-13 05:01:00        newark    tx      us  circle
# ...                   ...           ...   ...     ...     ...
# 79236 2012-09-04 08:56:00  rancho viejo    tx      us  circle
# 79381 2008-09-05 20:45:00         pecos    tx      us  circle
# 79750 2003-09-07 22:00:00       cypress    tx      us  circle
# 79867 2013-09-07 21:30:00       houston    tx      us  circle
# 80240 2009-09-09 19:32:00    fort worth    tx      us  circle
#
#       duration (seconds) duration (hours/min)  \
# 3                     20             1/2 hour
# 36                    60             1 minute
# 798                    2              seconds
# ...

# %%
ufos[(ufos['state']=='tx') & (ufos['shape']=='circle')].loc[3, 'comments']
# Out:
# 'My older brother and twin sister were leaving the only Edna theater at about 9 PM&#44...we had our bikes and I took a different route home'

# %%
ufos[(ufos['state']=='tx') & (ufos['shape']=='circle')].index
# Out:
# Int64Index([    3,    36,   798,  1046,  1449,  1651,  1665,  1760,  1831,
#              1865,
#             ...
#             77455, 78012, 78283, 78765, 78904, 79236, 79381, 79750, 79867,
#             80240],
#            dtype='int64', length=306)
