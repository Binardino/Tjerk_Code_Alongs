# %%
from sklearn import datasets
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
iris = datasets.load_iris()

# %%
iris_df = pd.DataFrame(iris['data'], columns=iris['feature_names'])

# %%
iris_df['target'] = iris.target

# %%
iris_df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      target
# 0         0
# ...

# %%
iris_df['sepal length (cm)'].plot(kind='bar')

# %%
fig, ax = plt.subplots(2, 2, figsize=(20, 10))
ax[0, 1].bar(iris_df.target, iris_df['sepal length (cm)'])
ax[0, 1].set_title('hello')
ax[0, 1].set_xlabel('flower species')
ax[0, 1].set_ylim(0, 10)
ax[0, 0].bar(iris_df.index, iris_df['sepal length (cm)'])
# Out:
# <BarContainer object of 150 artists>

# %%
sns.barplot(iris_df.target, iris_df['sepal length (cm)'])

# %%
plt.subplots( figsize=(20,10))
x = sns.countplot(x=iris_df['sepal length (cm)'], color='blue')
x.set_title('Sepal length count')
# Out:
# Text(0.5, 1.0, 'Sepal length count')

# %%
plt.subplots( figsize=(20,10))
plt.bar(sorted(iris_df['sepal length (cm)'].unique()), iris_df['sepal length (cm)'].value_counts().sort_index())
# Out:
# <BarContainer object of 35 artists>

# %%
sorted(iris_df['sepal length (cm)'].unique())
# Out:
# [4.3,
#  4.4,
#  4.5,
#  4.6,
#  4.7,
#  4.8,
#  4.9,
#  5.0,
#  5.1,
#  5.2,
#  5.3,
#  5.4,
#  5.5,
#  5.6,
#  5.7,
#  5.8,
#  5.9,
#  6.0,
#  6.1,
#  6.2,
#  6.3,
#  6.4,
#  6.5,
#  6.6,
#  6.7,
#  6.8,
#  6.9,
#  7.0,
#  7.1,
#  7.2,
#  7.3,
#  7.4,
#  7.6,
#  7.7,
#  7.9]

# %%
iris_df['sepal length (cm)'].value_counts().sort_index()
# Out:
# 4.3     1
# 4.4     3
# 4.5     1
# 4.6     4
# 4.7     2
# 4.8     5
# 4.9     6
# 5.0    10
# 5.1     9
# 5.2     4
# 5.3     1
# 5.4     6
# 5.5     7
# 5.6     6
# 5.7     8
# 5.8     7
# 5.9     3
# 6.0     6
# 6.1     6
# 6.2     4
# 6.3     9
# 6.4     7
# 6.5     5
# 6.6     2
# 6.7     8
# 6.8     3
# 6.9     4
# 7.0     1
# 7.1     1
# 7.2     3
# 7.3     1
# 7.4     1
# 7.6     1
# 7.7     4
# 7.9     1
# Name: sepal length (cm), dtype: int64

# %%
sns.pairplot(iris_df, hue='target')
# Out:
# /usr/local/lib/python3.7/site-packages/statsmodels/nonparametric/kde.py:487: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# /usr/local/lib/python3.7/site-packages/statsmodels/nonparametric/kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2

# %%
fig, ax = plt.subplots()
sns.lineplot(iris_df['sepal length (cm)'].index, iris_df['sepal length (cm)'], ax=ax, legend='brief')
sns.lineplot(iris_df['sepal width (cm)'].index, iris_df['sepal width (cm)'], ax=ax, legend='brief')
ax.legend(['length', 'width'])
ax.set_xticklabels([1,2,3,4,5])
ax.set_ylabel('cm')
# Out:
# Text(0, 0.5, 'cm')

# %%
plt.bar()

# %%
import plotly.express as px
df = px.data.iris()
fig = px.scatter(df, x="sepal_width", y="sepal_length")
fig.show()
